# %%
#ask the user for their name and capitalize the first alphabet and strip of any additional space if provided by the user

name = input("Enter your name: ").title().strip()

#say hello to user 

print(f"Hello, {name}")
# Out:
# Hello, Vikram

# %%
# Arithmatic operations 


x = float(input("value of x: "))
y = float(input("value of y: "))

sum = x + y
product = x*y 
difference = x - y 
quotient = x/y
remainder = x%y

arithematic_results = [("sum",sum), ("product",product), ("difference",difference) , ("quotient",quotient) , ("remainder",remainder)]

for label,result in arithematic_results:
    print(f"{label}: {result}")
# Out:
# sum: 7.0
# product: 12.0
# difference: -1.0
# quotient: 0.75
# remainder: 3.0

# %%
# defining a simple problem

def main():
    x = float(input("Enter the value of x: "))
    print(f"The {x} squared is {square(x)}")

def square(n):
    return pow(n,2)

main()
# Out:
# The 4.0 squared is 16.0

# %%
def even_or_odd():
    while True:
        num = input("Enter a positive integer to check or the word 'End' to end ==>  ").strip()

        if num.lower() == 'end':
            print("Bye bye")
            break

        elif num.isdigit():
            num = int(num)
            if num > 0:  #  ensures positive integer
                print(f"The {num} is {'even' if num % 2 == 0 else 'odd'}")
            else:
                print("Zero is not a positive integer!")
        else:
            print(f"Do you really think {num} is a positive integer?")

# call the function
even_or_odd()
# Out:
# The 1 is odd
# Bye bye

# %%
def hogwarts_records():
    alumni_data = {
        "Gryffindor": ("Ron", "Hermione", "Harry"),
        "Slytherin": ("Draco", "Snape"),
        "Ravenclaw": ("Luna", "Cho"),
        "Hufflepuff": ("Cedric", "Ginny")
    }

    name = input("Enter the student Name: ").strip().title()

    print(
        next(
            (f"{name} is from the house: {house}" 
             for house, students in alumni_data.items() if name in students),
            f"{name} is not in Hogwarts records."
        )
    )

# Call the function
hogwarts_records()
# Out:
# Ron is from the house: Gryffindor

# %%
i = 3

while i != 1:
    i = i - 1 
    print("meow")
# Out:
# meow
# meow

# %%
import random

# Rock, Paper, Scissors Game

choices = ["rock", "paper", "scissors"]

user_score = 0
computer_score = 0

while True:
    user_choice = input("Enter rock, paper, scissors or 'stop' to end: ").strip().lower()
    computer_choice = random.choice(choices)

    if user_choice == "stop":
        print(f"\nGame Ended. Thank You.\nUser Score: {user_score}\nComputer Score: {computer_score}")
        break

    if user_choice not in choices:
        print(f"Invalid choice! Please choose from {choices}.")
        continue

    print(f"Computer chose: {computer_choice}")

    if (
        (user_choice == "rock" and computer_choice == "scissors") or
       (user_choice == "paper" and computer_choice == "rock") or 
       (user_choice == "scissors" and computer_choice == "paper")
       
    ):
        user_score += 1
        print(f"You won this round!\nUser Score: {user_score}\nComputer Score: {computer_score}")
    elif user_choice == computer_choice:
        print(f"It's a tie!\nUser Score: {user_score}\nComputer Score: {computer_score}")
    else:
        computer_score += 1
        print(f"Computer won this round!\nUser Score: {user_score}\nComputer Score: {computer_score}")
# Out:
# Computer chose: rock
# It's a tie!
# User Score: 0
# Computer Score: 0
# Computer chose: rock
# You won this round!
# User Score: 1
# Computer Score: 0
#
# Game Ended. Thank You.
# User Score: 1
# Computer Score: 0

# %%
i = 3

while i != 1:
    i = i - 1 
    print("meow")
# Out:
# meow
# meow

# %%
       print("#\n" *3 , end = "")
# Out:
# #
# #
# #

# %%
n = 4
for i in range(n):
    for j in range(n -1 , 1):
        print("#", end = "")
    print()
